# %% [markdown]
# <h1>Coffee Trends</h1>

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
coffeePriceTrends = pd.read_excel("../Datasets/Price_Trend_1992_93_2015_USD.xls")

# %%
coffeePriceTrends = coffeePriceTrends.drop(['Unnamed: 0', 'Unnamed: 9'],
                      axis=1,
                      )

# %%
coffeePriceTrends
# Out:
#                                             Unnamed: 1      Unnamed: 2  \
# 0    AVERAGE PRICES PAID TO FARMERS AND PROCESSORS ...             NaN
# 1    DEC 2013 IN UGANDA SHILLINGS PER KILOGRAM  (U ...             NaN
# 2                                                  NaN             Shs
# 3                                                MONTH  ROBUSTA KIBOKO
# 4                                  1992-07-01 00:00:00             210
# ..                                                 ...             ...
# 280                                2015-07-01 00:00:00            2200
# 281                                2015-08-01 00:00:00            2200
# 282                                2015-09-01 00:00:00            2150
# 283                                                NaN             NaN
# 284                              Source: UCDA Database             NaN
#
#       Unnamed: 3         Unnamed: 4     Unnamed: 5      Unnamed: 6  \
# 0            NaN                NaN            NaN             NaN
# 1            NaN                NaN            NaN             NaN
# 2            NaN                NaN            NaN               $
# 3    ROBUSTA FAQ  ARABICA PARCHMENT  EX.RATE Sh/Kg  ROBUSTA KIBOKO
# 4            420                499        1177.86        0.178289
# ..           ...                ...            ...             ...
# 280         4350               5850        3360.09        0.654744
# 281         4500               6250        3548.25        0.620024
# 282         4250               5750         3667.5         0.58623
# 283          NaN                NaN            NaN             NaN
# 284          NaN                NaN            NaN             NaN
#
#       Unnamed: 7         Unnamed: 8
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3    ROBUSTA FAQ  ARABICA PARCHMENT
# 4       0.356579            0.42365
# ..           ...                ...
# 280     1.294608           1.741025
# 281     1.268231           1.761432
# 282     1.158828           1.567825
# 283          NaN                NaN
# 284          NaN                NaN
#
# [285 rows x 8 columns]

# %%
columnNames = coffeePriceTrends.loc[3].tolist()

# %%
columnNames
# Out:
# ['MONTH',
#  'ROBUSTA KIBOKO',
#  'ROBUSTA FAQ',
#  'ARABICA PARCHMENT',
#  'EX.RATE Sh/Kg',
#  'ROBUSTA KIBOKO',
#  'ROBUSTA FAQ',
#  'ARABICA PARCHMENT']

# %%
coffeePriceTrends.drop(coffeePriceTrends.index[:4], inplace=True,
                       axis=0,
                      )

# %%
coffeePriceTrends
# Out:
#                 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 4      1992-07-01 00:00:00        210        420        499    1177.86
# 5      1992-08-01 00:00:00        220        440        500    1185.29
# 6      1992-09-01 00:00:00        215        400        502    1185.15
# 7      1992-10-01 00:00:00        225        450        510    1181.07
# 8      1992-11-01 00:00:00        250        500        550    1196.34
# ..                     ...        ...        ...        ...        ...
# 280    2015-07-01 00:00:00       2200       4350       5850    3360.09
# 281    2015-08-01 00:00:00       2200       4500       6250    3548.25
# 282    2015-09-01 00:00:00       2150       4250       5750     3667.5
# 283                    NaN        NaN        NaN        NaN        NaN
# 284  Source: UCDA Database        NaN        NaN        NaN        NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8
# 4     0.178289   0.356579    0.42365
# 5     0.185609   0.371217   0.421838
# 6     0.181412    0.33751   0.423575
# 7     0.190505    0.38101   0.431812
# 8     0.208971   0.417941   0.459736
# ..         ...        ...        ...
# 280   0.654744   1.294608   1.741025
# 281   0.620024   1.268231   1.761432
# 282    0.58623   1.158828   1.567825
# 283        NaN        NaN        NaN
# 284        NaN        NaN        NaN
#
# [281 rows x 8 columns]

# %%
oldColumnNames = coffeePriceTrends.columns.tolist()

# %%
oldColumnNames
# Out:
# ['Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8']

# %%
{oldColumnNames[x]:columnNames[x] for x in range(len(columnNames))}
# Out:
# {'Unnamed: 1': 'MONTH',
#  'Unnamed: 2': 'ROBUSTA KIBOKO',
#  'Unnamed: 3': 'ROBUSTA FAQ',
#  'Unnamed: 4': 'ARABICA PARCHMENT',
#  'Unnamed: 5': 'EX.RATE Sh/Kg',
#  'Unnamed: 6': 'ROBUSTA KIBOKO',
#  'Unnamed: 7': 'ROBUSTA FAQ',
#  'Unnamed: 8': 'ARABICA PARCHMENT'}

# %%
columnNames
# Out:
# ['MONTH',
#  'ROBUSTA KIBOKO',
#  'ROBUSTA FAQ',
#  'ARABICA PARCHMENT',
#  'EX.RATE Sh/Kg',
#  'ROBUSTA KIBOKO',
#  'ROBUSTA FAQ',
#  'ARABICA PARCHMENT']

# %%
coffeePriceTrends = coffeePriceTrends.rename(columns={oldColumnNames[x]:columnNames[x] for x in range(len(columnNames))})

# %%
coffeePriceTrends = coffeePriceTrends.set_index('MONTH')

# %%
coffeePriceTrends
# Out:
#                       ROBUSTA KIBOKO ROBUSTA FAQ ARABICA PARCHMENT  \
# MONTH
# 1992-07-01 00:00:00              210         420               499
# 1992-08-01 00:00:00              220         440               500
# 1992-09-01 00:00:00              215         400               502
# 1992-10-01 00:00:00              225         450               510
# 1992-11-01 00:00:00              250         500               550
# ...                              ...         ...               ...
# 2015-07-01 00:00:00             2200        4350              5850
# 2015-08-01 00:00:00             2200        4500              6250
# 2015-09-01 00:00:00             2150        4250              5750
# NaN                              NaN         NaN               NaN
# Source: UCDA Database            NaN         NaN               NaN
#
#                       EX.RATE Sh/Kg ROBUSTA KIBOKO ROBUSTA FAQ  \
# MONTH
# 1992-07-01 00:00:00         1177.86       0.178289    0.356579
# 1992-08-01 00:00:00         1185.29       0.185609    0.371217
# 1992-09-01 00:00:00         1185.15       0.181412     0.33751
# 1992-10-01 00:00:00         1181.07       0.190505     0.38101
# 1992-11-01 00:00:00         1196.34       0.208971    0.417941
# ...                             ...            ...         ...
# 2015-07-01 00:00:00         3360.09       0.654744    1.294608
# 2015-08-01 00:00:00         3548.25       0.620024    1.268231
# 2015-09-01 00:00:00          3667.5        0.58623    1.158828
# NaN                             NaN            NaN         NaN
# Source: UCDA Database           NaN            NaN         NaN
#
#                       ARABICA PARCHMENT
# MONTH
# 1992-07-01 00:00:00             0.42365
# 1992-08-01 00:00:00            0.421838
# 1992-09-01 00:00:00            0.423575
# 1992-10-01 00:00:00            0.431812
# 1992-11-01 00:00:00            0.459736
# ...                                 ...
# 2015-07-01 00:00:00            1.741025
# 2015-08-01 00:00:00            1.761432
# 2015-09-01 00:00:00            1.567825
# NaN                                 NaN
# Source: UCDA Database               NaN
#
# [281 rows x 7 columns]

# %%
index = pd.MultiIndex.from_arrays([["UGX", "UGX", "UGX", "EX.RATE", "USD", "USD", "USD"],
                                   ["ROBUSTA KIBOKO", "ROBUSTA FAQ", "ARABICA PARCHMENT", "EX.RATE Sh/Kg", "ROBUSTA KIBOKO", "ROBUSTA FAQ", "ARABICA PARCHMENT"]])

# %%
coffeePriceTrends.columns = index

# %%
coffeePriceTrends
# Out:
#                                  UGX                                \
#                       ROBUSTA KIBOKO ROBUSTA FAQ ARABICA PARCHMENT
# MONTH
# 1992-07-01 00:00:00              210         420               499
# 1992-08-01 00:00:00              220         440               500
# 1992-09-01 00:00:00              215         400               502
# 1992-10-01 00:00:00              225         450               510
# 1992-11-01 00:00:00              250         500               550
# ...                              ...         ...               ...
# 2015-07-01 00:00:00             2200        4350              5850
# 2015-08-01 00:00:00             2200        4500              6250
# 2015-09-01 00:00:00             2150        4250              5750
# NaN                              NaN         NaN               NaN
# Source: UCDA Database            NaN         NaN               NaN
#
#                             EX.RATE            USD              \
#                       EX.RATE Sh/Kg ROBUSTA KIBOKO ROBUSTA FAQ
# MONTH
# 1992-07-01 00:00:00         1177.86       0.178289    0.356579
# 1992-08-01 00:00:00         1185.29       0.185609    0.371217
# 1992-09-01 00:00:00         1185.15       0.181412     0.33751
# 1992-10-01 00:00:00         1181.07       0.190505     0.38101
# 1992-11-01 00:00:00         1196.34       0.208971    0.417941
# ...                             ...            ...         ...
# 2015-07-01 00:00:00         3360.09       0.654744    1.294608
# 2015-08-01 00:00:00         3548.25       0.620024    1.268231
# 2015-09-01 00:00:00          3667.5        0.58623    1.158828
# NaN                             NaN            NaN         NaN
# Source: UCDA Database           NaN            NaN         NaN
#
#
#                       ARABICA PARCHMENT
# MONTH
# 1992-07-01 00:00:00             0.42365
# 1992-08-01 00:00:00            0.421838
# 1992-09-01 00:00:00            0.423575
# 1992-10-01 00:00:00            0.431812
# 1992-11-01 00:00:00            0.459736
# ...                                 ...
# 2015-07-01 00:00:00            1.741025
# 2015-08-01 00:00:00            1.761432
# 2015-09-01 00:00:00            1.567825
# NaN                                 NaN
# Source: UCDA Database               NaN
#
# [281 rows x 7 columns]

# %%
# stats = []
# for cl in coffeePriceTrends.columns:
#     stats.append((cl,
#                   coffeePriceTrends[cl].nunique(),
#                   coffeePriceTrends[cl].isnull().sum(),
#                   coffeePriceTrends[cl].isnull().sum() * 100 / coffeePriceTrends.shape[0],
#                   coffeePriceTrends[cl].value_counts(normalize=True, dropna=False).values[0] * 100,
#                   coffeePriceTrends[cl].dtype))
# stats_df = pd.DataFrame(stats, columns=['Feature',
#                                         'Unique Values',
#                                         'Missing Values',
#                                         'Missing Values [%]',
#                                         'Values in the biggest category [%]',
#                                         'Datatype'])
# stats_df.sort_values('Missing Values [%]', ascending=False)

# %%
# ProfileReport(coffeePriceTrends,
#                                 title="Coffee",
#                             )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\multimethod\__init__.py:369, in multimethod.__call__(self, *args, **kwargs)
#     368 try:
# --> 369     return func(*args, **kwargs)
#     370 except TypeError as ex:
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\model\pandas\dataframe_pandas.py:35, in pandas_preprocess(config, df)
#      34 # Ensure that columns are strings
# ---> 35 df.columns = df.columns.astype("str")
#      36 return df
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\pandas\core\indexes\multi.py:3873, in MultiIndex.astype(self, dtype, copy)
#    3872 if not is_object_dtype(dtype):
# -> 3873     raise TypeError(
#    3874         "Setting a MultiIndex dtype to anything other than object "
#    3875         "is not supported"
#    3876     )
#    3877 if copy is True:
#
# TypeError: Setting a MultiIndex dtype to anything other than object is not supported
#
# The above exception was the direct cause of the following exception:
#
# DispatchError                             Traceback (most recent call last)
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\IPython\core\formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\profile_report.py:546, in ProfileReport._repr_html_(self)
#     544 def _repr_html_(self) -> None:
#     545     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 546     self.to_notebook_iframe()
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\profile_report.py:526, in ProfileReport.to_notebook_iframe(self)
#     524 with warnings.catch_warnings():
#     525     warnings.simplefilter("ignore")
# --> 526     display(get_notebook_iframe(self.config, self))
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\profile_report.py:496, in ProfileReport.to_html(self)
#     488 def to_html(self) -> str:
#     489     """Generate and return complete template as lengthy string
#     490         for using with frameworks.
#     491
#    (...)
#     494
#     495     """
# --> 496     return self.html
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\profile_report.py:292, in ProfileReport.html(self)
#     289 @property
#     290 def html(self) -> str:
#     291     if self._html is None:
# --> 292         self._html = self._render_html()
#     293     return self._html
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\profile_report.py:409, in ProfileReport._render_html(self)
#     406 def _render_html(self) -> str:
#     407     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 409     report = self.report
#     411     with tqdm(
#     412         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     413     ) as pbar:
#     414         html = HTMLReport(copy.deepcopy(report)).render(
#     415             nav=self.config.html.navbar_show,
#     416             offline=self.config.html.use_local_assets,
#    (...)
#     424             version=self.description_set.package["ydata_profiling_version"],
#     425         )
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\profile_report.py:286, in ProfileReport.report(self)
#     283 @property
#     284 def report(self) -> Root:
#     285     if self._report is None:
# --> 286         self._report = get_report_structure(self.config, self.description_set)
#     287     return self._report
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\profile_report.py:268, in ProfileReport.description_set(self)
#     265 @property
#     266 def description_set(self) -> BaseDescription:
#     267     if self._description_set is None:
# --> 268         self._description_set = describe_df(
#     269             self.config,
#     270             self.df,
#     271             self.summarizer,
#     272             self.typeset,
#     273             self._sample,
#     274         )
#     275     return self._description_set
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\model\describe.py:60, in describe(config, df, summarizer, typeset, sample)
#      57     raise ValueError("Can not describe a `lazy` ProfileReport without a DataFrame.")
#      59 check_dataframe(df)
# ---> 60 df = preprocess(config, df)
#      62 number_of_tasks = 5
#      64 with tqdm(
#      65     total=number_of_tasks,
#      66     desc="Summarize dataset",
#      67     disable=not config.progress_bar,
#      68     position=0,
#      69 ) as pbar:
#
# File D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\multimethod\__init__.py:371, in multimethod.__call__(self, *args, **kwargs)
#     369     return func(*args, **kwargs)
#     370 except TypeError as ex:
# --> 371     raise DispatchError(f"Function {func.__code__}") from ex
#
# DispatchError: Function <code object pandas_preprocess at 0x0000022C905ECA50, file "D:\PyData Kampala\PyDataCurriculum\PyDataVenv\Lib\site-packages\ydata_profiling\model\pandas\dataframe_pandas.py", line 16>
